# %%
import matplotlib.pyplot as plt
import numpy as np
# %run -i func_proj_reconst.ipynb

# %%
N_t = 100
N_p = 200
theta = np.linspace(1e-6, np.pi, N_t) 
phi = np.linspace(0, 2*np.pi, N_p)  
t, p = np.meshgrid(theta, phi)

# %%
u1_nm_10 = np.load('u1_nm_10.npy')
u1_nm_15 = np.load('u1_nm_15.npy')
u1_nm_20 = np.load('u1_nm_20.npy')
u1_nm_30 = np.load('u1_nm_30.npy')
u1_nm_40 = np.load('u1_nm_40.npy')
u1_nm_60 = np.load('u1_nm_60.npy')
u1_nm_80 = np.load('u1_nm_80.npy')
plt.plot(u1_nm_10, label='lMax=10', color='red')
# plt.plot(u1_nm_15, label='lMax=15', color='pink')
# plt.plot(u1_nm_20, label='lMax=20', color='blue')
# plt.plot(u1_nm_30, label='lMax=30', color='black')
# plt.plot(u1_nm_40, label='lMax=40', color='orange')
plt.plot(u1_nm_80, label='lMax=80', color='green')
plt.title('u1_nm')
# Out:
# Text(0.5, 1.0, 'u1_nm')

# %%
plt.plot(u1_nm_80, label='lMax=80', color='green')
plt.title('u1_nm')
# Out:
# Text(0.5, 1.0, 'u1_nm')

# %%
#print ("max difference between analytical and numerical u1_nm\n",np.amax(np.abs(u1_nm_10-u1_nm_80)))

# %%
zeta_nm_a_10 = np.load('zeta_nm_a_10.npy')
zeta_nm_a_15 = np.load('zeta_nm_a_15.npy')
zeta_nm_a_20 = np.load('zeta_nm_a_20.npy')
zeta_nm_a_30 = np.load('zeta_nm_a_30.npy')
zeta_nm_a_40 = np.load('zeta_nm_a_40.npy')
zeta_nm_a_60 = np.load('zeta_nm_a_60.npy')
zeta_nm_a_80 = np.load('zeta_nm_a_80.npy')
plt.plot(zeta_nm_a_10, label='lMax=10', color='red')
# plt.plot(zeta_nm_a_15, label='lMax=15', color='pink')
# plt.plot(zeta_nm_a_20, label='lMax=20', color='blue')
# plt.plot(zeta_nm_a_30, label='lMax=30', color='black')
# plt.plot(zeta_nm_a_40, label='lMax=40', color='orange')
plt.plot(zeta_nm_a_80, label='lMax=80', color='green')
plt.title('zeta_nm_a')
# Out:
# Text(0.5, 1.0, 'zeta_nm_a')

# %%
#print ("max difference between analytical and numerical zeta_nm_a\n",np.amax(np.abs(zeta_nm_a_10-zeta_nm_a_80)))
